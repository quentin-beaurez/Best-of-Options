# %% [markdown]
# **PRB222 - Best of**

# %%
import numpy as np 
import numpy.random as npr
import matplotlib.pyplot as plt

# %% [markdown]
# Simuler un mouvement brownien standard $W=(W_1, W_2, W_3)$, de matrice de covariance $\Gamma$ donnée. On suppose que $$ \mathbf{E}(W) = 0_{\R^3} $$

# %%
rho = 0
Gamma = np.array ([1, rho, rho],
                  [rho, 1, rho], 
                  [1, rho, rho])

A = np.linalg.cholesky(Gamma) 

# On a : W = A
